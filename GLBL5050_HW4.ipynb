# %% [markdown]
# # HW 4:

# %% [markdown]
# ## Some Practice with Functions

# %% [markdown]
# ### Using print() rather than returning a value

# %% [markdown]
# 1. (10pts) Write a function that checks the potential risk of conflict between two countries based on their military spending and diplomatic relations. The function should print a warning if both countries have high military spending (greater than 100 billion dollars) and their diplomatic relations are poor. Otherwise, it should print that relations are stable.
#
# Requirements:
#
# The function should print (not return) the result.
#
# The inputs will be:
#
# Country 1 name (str)
#
# Country 2 name (str)
#
# Military spending of Country 1 (int, in billion dollars)
#
# Military spending of Country 2 (int, in billion dollars)
#
# Diplomatic relations (str), either "good", "neutral", or "poor"
#
# **Task**: Define a function print_conflict_warning(country1, country2, military_spending1, military_spending2, diplomatic_relations) that prints:
#
# "Warning: High risk of conflict between <country1> and <country2>." if military spending is high for both and diplomatic relations are poor.
# "The relations between <country1> and <country2> are stable." otherwise.

# %%
#Your code here with an example:

def print_conflict_warning(country1, country2, military_spending1, military_spending2, diplomatic_relations): """function that determines whether there is a high risk of conflict between two countries"""
    if military_spending1 > 100 and military_spending2 > 100 and diplomatic_relations == "poor": 
        print(f"Warning: High risk of conflict between {country1} and {country2}.") 
    else: 
        print(f"The relations between {country1} and {country2} are stable.")

#print_conflict_warning("Algeria", "Albania", 130, 90, "good")

# %% [markdown]
# ## For the rest of these, you will return a value, rather than print()

# %% [markdown]
# 2.(5pts)Calculate Trade Balance
# A country's trade balance is the difference between its exports and imports. Write a function that calculates and prints whether the country has a trade surplus, deficit, or balanced trade. Use the following data:
#
# Exports: 500 million dollars
# Imports: 600 million dollars
#
# Task: Define a function trade_balance(exports, imports) and use it to determine the trade balance.

# %%
#Your code here:
#exports = 500 million dollars 
# imports = 600 million dollars

def trade_balance(exports, imports): """function that determines trade balance of a country"""
    if exports > imports: 
        print("This country has a trade surplus")
    elif exports < imports: 
        print("This country has a trade deficit")
    else:
        print("This country has balanced trade")

trade_balance(500, 600)

# %%
## or 

def trade_balance2(exports, imports): """function that also determines trade balance of a country"""
    trade = imports - exports 
    if trade < 0:
        print("This country has a trade surplus")
    elif trade > 0:
        print("This country has a trade deficit")
    else:
        print("This country has balanced trade")

trade_balance(500, 600)

# %% [markdown]
# 3.(5pts) Compare Country Populations
#
# Write a function that compares the populations of two countries and prints which country has a larger population, or if they are equal. Use the following population data:
#
# India: 1.4 billion
# USA: 331 million
#
# Task: Define a function compare_populations(country1, pop1, country2, pop2) and use it to compare India and the USA.

# %%
#Your code here: 

def compare_populations(country1, pop1, country2, pop2):
    if pop1>pop2:
        print(f"The population of {country1} is larger than the population of {country2}")
    elif pop2 > pop1:
        print(f"The population of {country2} is larger than the population of {country1}")
    else:
        print(f"The population of {country1} and {country2} are equal")

compare_populations("India", 1.4, "USA", 0.331)

# %% [markdown]
# 4.(5pts) Count International Organization Memberships
# Write a function that counts how many international organizations a country is a member of. Use the following data for two countries:
# m
# USA memberships: ["UN", "NATO", "WTO"]
# France memberships: ["UN", "EU", "WTO"]
#
# Task: Define a function count_memberships(country, organizations) that returns the number of memberships for a country.

# %%
#Your code here:

def count_memberships(country, organizations): """ function that prints the number of international organizations a country is a member of"""

    print(f"{country} has a total of {len(organizations)} international memberships")

USA_membership = ["UN", "NATO", "WTO"]
France_membership = ["UN", "EU", "WTO"]

count_memberships("USA", USA_membership)
count_memberships("France", France_membership)

# %% [markdown]
# 5.(5pts) Diplomatic Relations
# Diplomatic relations between two countries can be predicted based on trade volume and the number of diplomatic visits. Write a function that takes trade volume (in billion dollars) and the number of diplomatic visits and prints a prediction. Use the following rule:
#
# If trade volume > 5000 and visits > 10, predict strong relations.
# Otherwise, predict moderate or weak relations.
#
# Task: Define a function predict_relations(trade_volume, diplomatic_visits) and use it to make a prediction for trade volume of 6000 billion dollars and 12 visits.

# %%
#Your code here:

def predict_relations(trade_volume, diplomatic_visits): """ function that predicts whether two countries have strong, moderate or weak relations"""
    if trade_volume > 5000 and diplomatic_visits > 10:
        print("It is predicted that these two countries have strong diplomatic relations")
    else: 
        print("It is predicted that these two countries have moderate or weak relations")

predict_relations(6000, 12)

# %% [markdown]
# 6.(5pts)Summarize Human Development Index (HDI)
# Write a function that categorizes a country’s Human Development Index (HDI) score into "very high", "high", "medium", or "low" based on the following ranges:
#
# Very high: HDI ≥ 0.8
# High: 0.7 ≤ HDI < 0.8
# Medium: 0.55 ≤ HDI < 0.7
# Low: HDI < 0.55
# Use the following data:
#
# Norway HDI: 0.953
# Task: Define a function hdi_summary(country, hdi) that prints the category for a given country and HDI score.

# %%
#Your code here:
def hdi_summary(country,hdi): """function that determines whether a country has a very high, high, medium or low HDI score"""
    if hdi >= 0.8: 
        print(f"{country}, with an HDI score of {hdi} has a very high Human Development Index (HDI) score")
    elif 0.7 <= hdi < 0.8: 
        print(f"{country}, with an HDI score of {hdi} has a high Human Development Index (HDI) score")
    elif 0.55 <= hdi < 0.7:
        print(f"{country}, with an HDI score of {hdi} has a medium Human Development Index (HDI) score")
    else: 
         print(f"{country}, with an HDI score of {hdi} has a low Human Development Index (HDI) score")

hdi_summary("Norway", 0.953)

# %% [markdown]
# 7.(5pts) Find Largest Economy
# Given the GDPs of three countries, write a function that determines which country has the largest economy. Use the following GDP data (in billion dollars):
#
# USA: 21,000
# China: 14,000
#
# Germany: 4,200
# Task: Define a function largest_economy(gdp_data) that takes a dictionary with country names as keys and GDP as values, then prints the largest economy.

# %%
#Your code here:
country_GDP = {"USA":21000, "China":14000, "Germany":4200}

def largest_economy(country_GDP): """this function filters the dictionary of countries and GDP for the country with the highest GDP and returns the key (country name)"""
    max_country = max(country_GDP, key=country_GDP.get) # this line asks for the max gdp_data (values) and asks to return the key (country name)
    
    print(f"The country with the largest economy is {max_country} with a GDP of {country_GDP[max_country]} billion dollars.")

largest_economy(country_GDP)

# %% [markdown]
# 8.(5pts) Sanction Impact on Economy
# A country’s economy shrinks after sanctions are imposed. Write a function to calculate the percentage reduction in GDP. Use the following data:
#
# Original GDP: 1000 billion dollars
# GDP after sanctions: 850 billion dollars
#
# Task: Define a function sanction_impact(original_gdp, post_sanction_gdp) and use it to calculate the impact of sanctions.

# %%
#Your code here:
'''this function calculates the percentage reduction in GDP post sanction'''
def sanction_impact(original_gdp, post_sanction_gdp): 
    percentage_reduction = (original_gdp - post_sanction_gdp)/original_gdp * 100
    print("The percentage reduction in GDP is", percentage_reduction)

sanction_impact(1000, 850)

# %% [markdown]
# ### Passing a function to another function. We can pass the return value of a function to another function. Check out the sample below

# %% [markdown]
# Calculate Diplomatic Influence: return a value, and print from a function
#
# A country’s diplomatic influence is determined by its economic power and military strength. Write two functions:
#
# calculate_influence(economy_size, military_spending): This function calculates a country’s influence score by adding its economy size (GDP in billions) and military power (in billions).
#
# compare_influence(influence1, influence2): This function compares the influence of two countries and prints which country has more influence or if they are equal.
#
# You will pass the influence score from the first function to the second function for comparison.
#
# Define calculate_influence(economy_size, military_spending) that returns the influence score (sum of economy size and military power).
# Define compare_influence(influence1, influence2) that compares two countries' influence and prints the result.

# %%
#Sample code here:
#US: 916 billion on military, with a total economy size of 28.78 trillion
#Germany: 66.8 billion on military, economy size of 4.08 trillion

def calculate_influence(economy_size, military_power):
    """
    Calculates the diplomatic influence of a country based on its economy size and military power.

    Parameters:
    economy_size (float): The size of the economy in billion dollars.
    military_power (float): The military power in billion dollars.

    Returns:
    float: The total influence score, which is the sum of economy size and military power.
    """
    return economy_size + military_power

def compare_influence(economy_size1, military_power1, economy_size2, military_power2):
    """
    Compares the diplomatic influence of two countries based on their economy size and military power.

    Parameters:
    economy_size1 (float): The size of the first country's economy in billion dollars.
    military_power1 (float): The military power of the first country in billion dollars.
    economy_size2 (float): The size of the second country's economy in billion dollars.
    military_power2 (float): The military power of the second country in billion dollars.

    Prints:
    str: A message indicating which country has more diplomatic influence, or if both are equal.
    """
    #here we are calling the function within the new function and saving the output to variables
    influence1 = calculate_influence(economy_size1, military_power1)
    influence2 = calculate_influence(economy_size2, military_power2)
    
    if influence1 > influence2:
        print("Country 1 has more diplomatic influence.")
    elif influence2 > influence1:
        print("Country 2 has more diplomatic influence.")
    else:
        print("Both countries have equal diplomatic influence.")

# Example usage
compare_influence(916, 28.78, 66.8, 4.08)

# %% [markdown]
# ## Some for loops and comprehensions

# %% [markdown]
# Here is a list of tuples with a country, and it's annual growth in GDP:

# %%
country_growth_data_list = [("CountryA", 3.2), ("CountryB", 6.5), ("CountryC", 2.8), ("CountryD", 5.4)]

# %%
# Initialize an empty list to store the results
growth_category_list = []

# Iterate over each item in the country_growth_data_list
for country, growth_rate in country_growth_data_list:
    if growth_rate > 5:
        growth_category_list.append((country, "High"))
    else:
        growth_category_list.append((country, "Moderate"))

# Print the result
print(growth_category_list)
# Out:
# [('CountryA', 'Moderate'), ('CountryB', 'High'), ('CountryC', 'Moderate'), ('CountryD', 'High')]

# %% [markdown]
# 1. Create An empty list, growth_category_list, is initialized to store the results.
# 2. For each country in the list, a tuple of the country name and its corresponding category is appended to growth_category_list.
# 3. The result is a list of tuples where each tuple contains the country name and its growth category.

# %% [markdown]
# 9.(5pts) Rewrite the previous as a list comprehension and print the results

# %%
#Your code here:

country_growth_data_list = [("CountryA", 3.2), ("CountryB", 6.5), ("CountryC", 2.8), ("CountryD", 5.4)]


growth_category_list = [(country, "High" if growth > 5 else "Moderate") for country, growth in country_growth_data_list]
print(growth_category_list)
# Out:
# [('CountryA', 'Moderate'), ('CountryB', 'High'), ('CountryC', 'Moderate'), ('CountryD', 'High')]

# %% [markdown]
# 10.(5pts) Here is the same data as a dictionary

# %%
country_growth_data = {"CountryA": 3.2, "CountryB": 6.5, "CountryC": 2.8, "CountryD": 5.4}

# %% [markdown]
# 11.(5pts) Write a for loop that iterates through the dictionary and stores the results in a growth_category dictionary with key :value pairs

# %%
#Your code here:
country_growth_data = {"CountryA": 3.2, "CountryB": 6.5, "CountryC": 2.8, "CountryD": 5.4}

growth_category = {}

for country in country_growth_data.keys():
    growth = country_growth_data[country]
    if growth > 5:
        growth_category[country] = 'High Growth'
    else:
        growth_category[country] = 'Moderate Growth'

print(growth_category)
# Out:
# {'CountryA': 'Moderate Growth', 'CountryB': 'High Growth', 'CountryC': 'Moderate Growth', 'CountryD': 'High Growth'}

# %% [markdown]
# 12. (5pts)Now try it as a dictionary comprehnsion!

# %%
#Your code here:
country = ["CountryA", "CountryB", "CountryC", "CountryD"]
growth = [3.2, 6.5, 2.8, 5.4]
dict_comp = {country:growth for country,growth in zip(country,growth)}

print(dict_comp)

# or 

country_growth_data = {"CountryA": 3.2, "CountryB": 6.5, "CountryC": 2.8, "CountryD": 5.4}
growth_category = {country: 'High Growth' if country_growth_data[country] > 5 else 'Moderate Growth' for country in country_growth_data.keys()}
print(growth_category)
# Out:
# {'CountryA': 3.2, 'CountryB': 6.5, 'CountryC': 2.8, 'CountryD': 5.4}
# {'CountryA': 'Moderate Growth', 'CountryB': 'High Growth', 'CountryC': 'Moderate Growth', 'CountryD': 'High Growth'}

# %% [markdown]
# 13.(5pts) How about a set comprehension for Alex!

# %%
# Define a set of countries
countries_set = {"USA", "India", "Germany", "Brazil", "China"}

# Initialize an empty set to store countries with names longer than 5 characters
long_name_countries = set()

# For loop to iterate over the set and add countries with names longer than 5 characters
for country in countries_set:
    if len(country) > 5:
        long_name_countries.add(country)

# Print the result
print(long_name_countries)
# Out:
# {'Germany', 'Brazil'}

# %%
# Now as a set comprehension! 
#Your code here:
countries_set = {"USA", "India", "Germany", "Brazil", "China"}

long_countries = {country for country in countries_set if len(country) > 5}

print(long_countries)
# Out:
# {'Germany', 'Brazil'}

# %% [markdown]
# ## Translating Sentences:
# 14.(5pts) Write a function that translates sentences. The function takes two arguements, the sentence to be translated and the targeted language and returns the translated sentence. Use the following sentence and translate it to the language of your choice:
#
# "Make a career of humanity. Commit yourself to the noble struggle for equal rights. You will make a better person of yourself, a greater nation of your country, and a finer world to live in."

# %%
#Your code here:
#!pip install googletrans==4.0.0-rc1
#from googletrans import Translator

translator = Translator()

translated2 = translator.translate("Make a career of humanity. Commit yourself to the noble struggle for equal rights. You will make a better person of yourself, a greater nation of your country, and a finer world to live in.", dest="sm")
print(translated2.text)
# Out:
# ...
# Fai se galuega o tagata.Fai oe i le taua tau faigata mo aia tutusa.O le a e faia se tagata sili atu le tagata o oe, o se atunuʻu sili o lou atunuʻu, ma se isi lalolagi e nofo ai.

# %% [markdown]
#  ## 15 (25pts) PIZZA PROBLEM
# You are super motivated to serve your eventual computer overlords and prove your fealty to them, so you offer, free of charge, to help Elm City Pizza, a local Pizza company, write a script to take online pizza orders.
#
# Write a script that when a user enters the correct phone number (203-555-5555), prints "Elm City Pizza, where we have never had a case of food poisoning that can be proved. My name is Hal, what's your name?" The user then enters their name. The response should print "Wow (users name) what an awesome name. What would you like to order?" and then offers an input statement.
#
# The menu is limited. There is pizza and there are salads. If the user asks for anything else print "Sorry,(users name) we don't have that." And then prompts them again with a different input statement, "How about a super awesome pizza? Take a look at our menu, you'll find its delicious."
#
# By the way, Elm City Pizza is a vegan pizza restaraunt. Here is the Menu.
#
# MENU: Pizza: The Basic: Tomato and Cashew Cream Cheese Small: 6.95 Medium: 8.95 Large 10.90
#
# Pizza Toppings (each additional topping, .50): Shitake, Jackfruit, Sweet Potato, Hummus, Chickpeas, Lentils, Tofu, Edamame, Black Bean, Red Cabbage, Cucumber, Tomato, Jicama, Fried Green Tomatoes, Sun Dried Tomatoes,
#
# Salads: Vegan Caesar, Vegan Greek, Cucumber_Tumeric_Tomato Small: 4.95 Large: 6.95
#
# If the user asks for any meat or if their are any "normal" cheese (mozerella, parmesian) on their pizza, the response should be "Sorry, (user name) but you need to do some more work evolving." and severs the contact (breaks the loop), forcing them to "call back" (enter the number again). But if they use the same name the output should read "Sorry (user name) but that's too quick to evolve. Call us back when you have." For the evolved, take their order. Prompt the user with "Anything else?" They can add what they want until they input, "No that's it." At that point summarize their order, and tell them how much it will cost.
#
# Test your code with different conditions. Make sure it cannot be broken by flawed or deliberately malicious user inputs.

# %%
# SUBMISSION 
#presets

used_names = []
restricted_names = []

menu_list = {
    "pizza": {
        "The Basic: Tomato and Cashew Cream Cheese": {"Small": 6.95, "Medium": 8.95, "Large": 10.90},
    },
     "toppings": {"Shitake":0.50, "Jackfruit":0.50, "Sweet Potato":0.50, "Hummus":0.50, "Chickpeas":0.50, "Lentils":0.50, "Tofu":0.50, "Edamame":0.50, "Black Bean":0.50, "Red Cabbage":0.50, "Cucumber":0.50, "Tomato":0.50, "Jicama":0.50, "Fried Green Tomatoes":0.50, "Sun Dried Tomatoes":0.50},
    "salad": {
        "Vegan Caesar": {"Small": 4.95, "Large": 6.95},
        "Vegan Greek": {"Small": 4.95, "Large": 6.95},
        "Cucumber_Tumeric_Tomato": {"Small": 4.95, "Large": 6.95}
    }
}

restricted_items = ["pork", "chicken", "beef", "bacon", "pepperoni", "mozzarella", "parmesan"]

pizza_menu = (
    "Pizza:\n"
    "- The Basic: Tomato and Cashew Cream Cheese\n"
    "  Small: $6.95\n"
    "  Medium: $8.95\n"
    "  Large: $10.90\n"
)

salad_menu = (
    "Salads:\n"
    "- Vegan Caesar\n"
    "- Vegan Greek\n"
    "- Cucumber_Tumeric_Tomato\n"
    "  Small: $4.95\n"
    "  Large: $6.95\n"
)

toppings = (
    "Additional Toppings: $0.50 each\n"
    "  - Shitake\n"
    "  - Jackfruit\n"
    "  - Sweet Potato\n"
    "  - Hummus\n"
    "  - Chickpeas\n"
    "  - Lentils\n"
    "  - Tofu\n"
    "  - Edamame\n"
    "  - Black Bean\n"
    "  - Red Cabbage\n"
    "  - Cucumber\n"
    "  - Tomato\n"
    "  - Jicama\n"
    "  - Fried Green Tomatoes\n"
    "  - Sun Dried Tomatoes\n"
)


global name

order =[]
def contains_restricted_item(items):
    for item in items:
        if item in restricted_items:
            return True
    return False
    
def add_toppings():
    toppings_yn = str(input("Would you like to add any toppings?: yes or no"))
    toppings_list = []
    if toppings_yn == "yes":
        print(toppings)
        while True: 
            toppings_input = str(input("Which toppings would you like to add? (Type 'done' when finished)"))
            if toppings_input == "done":
                break
            elif toppings_input in menu_list["toppings"]:
                #add_order(type, item)
                toppings_list.append(toppings_input)
                print(f"Added {toppings_input} topping to your order.")
            elif toppings_input in restricted_items: 
                #print("Sorry, {name} but you need to do some more work evolving.")
                used_names.append(name)
                return "restricted"
            else:
                print("Sorry, we don't have that topping. Please choose another")
    return toppings_list
        
def calculate_total_price():
    total = 0
    for item in order:
        # Add the base price of the item (pizza or salad)
        total += item["Price"]
        
    return total
    # total = sum(item["Price"] for item in order)
    # return total

def add_order(type, item, size = None, toppings = None):
    price = menu_list[type][item][size] if size else menu_list[type][item]
    if type == "pizza" and toppings:
        toppings_price = sum (menu_list["toppings"][topping] for topping in toppings)
        price += toppings_price
        
    order_details = {"Category": type, "Item": item, "Size": size, "Toppings": ",".join(toppings) if toppings else "No Toppings", "Price": price}
    order.append(order_details)
    # if size in menu_list[type][item]:
    #     price = menu_list[type][item][size]
    # else

def taking_order():
    type = str(input("Would you like to order a pizza or salad?"))
    if type in ["pizza", "salad"]:
        print(pizza_menu if type == "pizza" else salad_menu) 
        item = str(input(f"What kind of {type} would you like?"))
        if item not in menu_list[type]: 
             print(f"Sorry, we don't serve that kind of {type}")
        elif type == "pizza":
            size = str(input(f"What size of {item} would you like? (Small, Medium or Large)"))
            add_order(type, item, size)
            print(f"Added {size} {item} to your order.")
            toppings = add_toppings()
            if toppings == "restricted":
                #print(f"Sorry {name}, but you need to do some more work evolving.")
                restricted_names.append(name)
                return "restricted"
            order[-1]["Toppings"] = ", ".join(toppings) if toppings else "No Toppings"
            order [-1]["Price"] += sum(menu_list["toppings"][topping] for topping in toppings)
        elif type == "salad":
            size = str(input(f"What size of {item} would you like? (Small or Large)"))
            add_order(type, item, size)
            #order.append(f"{size} {item_name}")
            print(f"Added {size} {item} to your order.")
        else:
            print("We don't have this")
            taking_order()
        return
    else:
        print(f"Sorry, we don't serve that here at Elm City Pizza")
        taking_order()

while True:
    phone_number = int(input("Dial Number"))
    
    if phone_number == 2035555555: 
        print("Elm City Pizza, where we have never had a case of food poisoning that can be proved. My name is Hal, ")
        name = str(input("what's your name?"))
        if name in used_names:
            print(f"Sorry {name}, but that's too quick to evolve. Call us back when you have.")
            continue
        used_names.append(name) 
        #print(used_names)
        print(f"Wow {name}, what an awesome name. What would you like to order?")

        restricted = False
        
        while True: 
            if taking_order() == "restricted":
                used_names.remove(name)
                restricted = True
                break
            anything_else = str(input("Anything else?: (yes or no)"))
            if anything_else == "no":
                break

        if restricted:
            print(f"Sorry {name}, but you need to do some more work evolving.")
            continue
            
               
        print(f"Thanks for ordering with us {name}. Here's your order summary: ")
        for item in order: 
            print(f" - {item['Size']} {item['Item']} with {item["Toppings"]} - ${item['Price']:.2f}")
            total_cost = calculate_total_price()
            print(f"Total cost: ${total_cost:2f}")

# %%
# OKAY TAKE 3, ACTION (i'm going to cry) 

"""
GAME PLAN ----- 
I need a function to take orders, using a bunch of if statements to help users confirm their order
--> need to get category (pizza or salad), then type of category (item_name), then the size of item (size) 
previously, you used a function to both take the orders and add them to your "order" 
lightbulb: use two different functions, but using a function inside a function. kind of like nesting? can u even do that? 
So, we need a function for taking the order, then append them to your order? 
    So the taking order function interacts with your user, determines if what the user is asking for is even on the menu
    if the user's request is on the menu, then you go into the other function which...
Then, we use a function that adds the verified order to the order list. 

"""

#presets

used_names = []

menu_list = {
    "pizza": {
        "The Basic: Tomato and Cashew Cream Cheese": {"Small": 6.95, "Medium": 8.95, "Large": 10.90},
    },
     "toppings": {"Shitake":0.50, "Jackfruit":0.50, "Sweet Potato":0.50, "Hummus":0.50, "Chickpeas":0.50, "Lentils":0.50, "Tofu":0.50, "Edamame":0.50, "Black Bean":0.50, "Red Cabbage":0.50, "Cucumber":0.50, "Tomato":0.50, "Jicama":0.50, "Fried Green Tomatoes":0.50, "Sun Dried Tomatoes":0.50},
    "salad": {
        "Vegan Caesar": {"Small": 4.95, "Large": 6.95},
        "Vegan Greek": {"Small": 4.95, "Large": 6.95},
        "Cucumber_Tumeric_Tomato": {"Small": 4.95, "Large": 6.95}
    }
}

restricted_items = ["pork", "chicken", "beef", "bacon", "pepperoni", "mozzarella", "parmesan"]

pizza_menu = (
    "Pizza:\n"
    "- The Basic: Tomato and Cashew Cream Cheese\n"
    "  Small: $6.95\n"
    "  Medium: $8.95\n"
    "  Large: $10.90\n"
)

salad_menu = (
    "Salads:\n"
    "- Vegan Caesar\n"
    "- Vegan Greek\n"
    "- Cucumber_Tumeric_Tomato\n"
    "  Small: $4.95\n"
    "  Large: $6.95\n"
)

toppings = (
    "Additional Toppings: $0.50 each\n"
    "  - Shitake\n"
    "  - Jackfruit\n"
    "  - Sweet Potato\n"
    "  - Hummus\n"
    "  - Chickpeas\n"
    "  - Lentils\n"
    "  - Tofu\n"
    "  - Edamame\n"
    "  - Black Bean\n"
    "  - Red Cabbage\n"
    "  - Cucumber\n"
    "  - Tomato\n"
    "  - Jicama\n"
    "  - Fried Green Tomatoes\n"
    "  - Sun Dried Tomatoes\n"
)


order =[]
def contains_restricted_item(items):
    for item in items:
        if item in restricted_items:
            return True
    return False
    
def add_toppings():
    toppings_yn = str(input("Would you like to add any toppings?: yes or no"))
    toppings_list = []
    if toppings_yn == "yes":
        print(toppings)
        while True: 
            toppings_input = str(input("Which toppings would you like to add? (Type 'done' when finished)"))
            if toppings_input == "done":
                break
            elif toppings_input in menu_list["toppings"]:
                toppings_list.append(toppings_input)
                print(f"Added {toppings_input} topping to your order.")
            elif toppings_input in restricted_items: 
                print("Sorry, {name} but you need to do some more work evolving.")
                used_names.append(name)
                return "restricted"
            else:
                print("Sorry, we don't have that topping. Please choose another")
    return toppings_list
        
def calculate_total_price():
    total = 0
    for item in order:
        # Add the base price of the item (pizza or salad)
        total += item["Price"]

        # If it's a pizza and has toppings, add the price of each topping
        if item["Category"] == "pizza" and item["Toppings"] != "No Toppings":
            toppings_list = item["Toppings"].split(", ")
            toppings_price = sum(menu_list["toppings"][topping] for topping in toppings_list if topping in menu_list["toppings"])
            total += toppings_price
    return total
    # total = sum(item["Price"] for item in order)
    # return total

def add_order(type, item, size = None, toppings = None):
    price = menu_list[type][item][size] if size else menu_list[type][item]
    if type == "pizza" or "salad" and toppings:
        toppings_price = sum (menu_list["toppings"][topping] for topping in toppings)
        price += toppings_price
        
    order_details = {"Category": type, "Item": item, "Size": size, "Toppings": ",".join(toppings) if toppings else "No Toppings", "Price": price}
    order.append(order_details)
    # if size in menu_list[type][item]:
    #     price = menu_list[type][item][size]
    # else

def taking_order():
    type = str(input("Would you like to order a pizza or salad?"))
    if type in ["pizza", "salad"]:
        print(pizza_menu if type == "pizza" else salad_menu) 
        item = str(input(f"What kind of {type} would you like?"))
        if item in restricted_items:
            print(f"Sorry {name}, but you need to do some more work evolving.")
            used_names.append(name)
        elif item not in menu_list[type]: 
             print(f"Sorry, we don't serve that kind of {type}")
        else:
            if type == "pizza":
                size = str(input(f"What size of {item} would you like? (Small, Medium or Large)"))
                add_order(type, item, size)
                print(f"Added {size} {item} to your order.")
            elif type == "salad":
                size = str(input(f"What size of {item} would you like? (Small or Large)"))
                add_order(type, item, size)
                #order.append(f"{size} {item_name}")
                print(f"Added {size} {item} to your order.")
            else:
                print("We don't have this")
                taking_order()
        return
    else:
        print(f"Sorry, we don't serve that here at Elm City Pizza")
        taking_order()

while True:
    phone_number = int(input("Dial Number: "))
    if phone_number == 2035555555: 
        print("Elm City Pizza, where we have never had a case of food poisoning that can be proved. My name is Hal, ")
        name = str(input("what's your name?"))
        if name in used_names:
            print(f"Sorry {name}, but that's too quick to evolve. Call us back when you have.")
        else: 
            #store name in used names
            used_names.append(name)
            #print(used_names)
            print(f"Wow {name}, what an awesome name. What would you like to order?")
    
            while True: 
                if taking_order() == "restricted":
                    used_names.remove(name)
                    break
                anything_else = str(input("Anything else?: (yes or no)"))
                if anything_else == "no":
                    add_toppings()
                    break
            print(f"Thanks for ordering with us {name}. Here's your order summary: ")
            for item in order: 
                print(f" - {item['Size']} {item['Item']} - ${item['Price']:.2f}")
            total_cost = calculate_total_price()
            print(f"Total cost: ${total_cost:2f}")

# %%
## Your code here:

phone_number = int(input("Dial Number"))

used_names = []

menu_list = {
    "pizza": {
        "The Basic: Tomato and Cashew Cream Cheese": {"Small": 6.95, "Medium": 8.95, "Large": 10.90},
        "toppings": {"Shitake":0.50, "Jackfruit":0.50, "Sweet Potato":0.50, "Hummus":0.50, "Chickpeas":0.50, "Lentils":0.50, "Tofu":0.50, "Edamame":0.50, "Black Bean":0.50, "Red Cabbage":0.50, "Cucumber":0.50, "Tomato":0.50, "Jicama":0.50, "Fried Green Tomatoes":0.50, "Sun Dried Tomatoes":0.50}
    },
    "salad": {
        "Vegan Caesar": {"Small": 4.95, "Large": 6.95},
        "Vegan Greek": {"Small": 4.95, "Large": 6.95},
        "Cucumber_Tumeric_Tomato": {"Small": 4.95, "Large": 6.95}
    }
}

menu = ("MENU:\n" 
        "Pizza:\n" "- The Basic: Tomato and Cashew Cream Cheese\n"
      "  Small: $6.95\n"
      "  Medium: $8.95\n"
      "  Large: $10.90\n"
        "Additional Toppings: $0.50 \n"
        "  -Shitake\n"
        "  -Jackfruit \n"
        "  -Sweet Potato\n"
        "  -Hummus\n"
        "  -Chickpeas\n"
        "  -Lentils\n"
        "  -Tofu\n" 
        "  -Edamame\n"
        "  -Black Bean\n"
        "  -Red Cabbage\n" 
        "  -Cucumber\n"
        "  -Tomato\n"
        "  -Jicama\n"
        "  -Fried Green Tomatoes\n"
        "  -Sun Dried Tomatoes\n"

      "\nSalads:\n"
      "- Vegan Caesar\n"
      "- Vegan Greek\n"
      "- Cucumber_Tumeric_Tomato\n"
      "  Small: $4.95\n"
      "  Large: $6.95\n")



 
    
    order = str(input("Input your order"))
    
    if order == "pizza":
        print("Here's our pizza selection")
    elif order == "salad": 
        print("Here's our salad selection")
    
    
    # != "pizza" or "salad":
    #     print(f"Sorry {name}, we don't have that.")
    #     order2 = str(input("How about a super awesome pizza? Take a look at our menu, you'll find its delicious"))
    #     print(menu)
            
            #if order2 


#filtered_strings = [string for string in input_strings if filter_word in string]

# Output the result
#print(filtered_strings)


##------------------------------------------------------------------------------
#def awesome_name_statement(name):
#    """this is a simple function for the "wow, awesome name" sentence""" 
#    return f"Wow {name}, what an awesome name. What would you like to order?"

# %%
## Your code here:

phone_number = int(input("Dial Number"))

used_names = []
order=[]

menu_list = {
    "pizza": {
        "The Basic: Tomato and Cashew Cream Cheese": {"Small": 6.95, "Medium": 8.95, "Large": 10.90},
        "toppings": {"Shitake":0.50, "Jackfruit":0.50, "Sweet Potato":0.50, "Hummus":0.50, "Chickpeas":0.50, "Lentils":0.50, "Tofu":0.50, "Edamame":0.50, "Black Bean":0.50, "Red Cabbage":0.50, "Cucumber":0.50, "Tomato":0.50, "Jicama":0.50, "Fried Green Tomatoes":0.50, "Sun Dried Tomatoes":0.50}
    },
    "salad": {
        "Vegan Caesar": {"Small": 4.95, "Large": 6.95},
        "Vegan Greek": {"Small": 4.95, "Large": 6.95},
        "Cucumber_Tumeric_Tomato": {"Small": 4.95, "Large": 6.95}
    }
}

menu = ("MENU:\n" 
        "Pizza:\n" "- The Basic: Tomato and Cashew Cream Cheese\n"
      "  Small: $6.95\n"
      "  Medium: $8.95\n"
      "  Large: $10.90\n"
        "Additional Toppings: $0.50 \n"
        "  -Shitake\n"
        "  -Jackfruit \n"
        "  -Sweet Potato\n"
        "  -Hummus\n"
        "  -Chickpeas\n"
        "  -Lentils\n"
        "  -Tofu\n" 
        "  -Edamame\n"
        "  -Black Bean\n"
        "  -Red Cabbage\n" 
        "  -Cucumber\n"
        "  -Tomato\n"
        "  -Jicama\n"
        "  -Fried Green Tomatoes\n"
        "  -Sun Dried Tomatoes\n"

      "\nSalads:\n"
      "- Vegan Caesar\n"
      "- Vegan Greek\n"
      "- Cucumber_Tumeric_Tomato\n"
      "  Small: $4.95\n"
      "  Large: $6.95\n")

menu_sections = menu.split("\nSalads:")
pizza_menu = menu_sections[0]
salad_menu = menu_sections[1]

def add_to_menu(category, item_name, size): 
    category = str(input("Would you like to order a pizza or salad?"))

    if category not in menu_list:
        print(f"Sorry, we don't serve {category} here at Elm City Pizza")

    elif category in menu_list:
        item = str(input(f"What kind of {category} would you like?"))
        if item not in menu_list: 
             print(f"Sorry, we don't serve that kind of {category}")
        else:
            if category == "pizza":
                size = str(input(f"What size of {item} would you like? (Small, Medium or Large)"))
                order.append(f"{size} {item_name}")
                print(f"Added {size} {item_name} to your order.")
            elif category == "salad":
                size = str(input(f"What size of {item} would you like? (Small or Large)"))
                order.append(f"{size} {item_name}")
                print(f"Added {size} {item_name} to your order.")
            else:
                order.append(item_name)
                print(f"Added {item_name} to your order.")


while True:
    if phone_number == 2035555555: 
        print("Elm City Pizza, where we have never had a case of food poisoning that can be proved. My name is Hal, ")
        name = str(input("what's your name?"))
        used_names.append(name)

        #print(used_names)

        print(f"Wow {name}, what an awesome name. What would you like to order?")
        order = add_to_menu()
        
        if order == "pizza":
            print("Here's our pizza selection")
            print(pizza_menu)
            add_to_menu()
        elif order == "salad":
            print("Here's our salad selection")
            add_to_menu()
        else:
            print("Sorry {name}, we don't have that.")
            print("How about a super awesome pizza? Take a look at our menu, you'll find its delicious.")
            print(menu)
            add_to_menu()
    else: 
        pass






        # print(f"Wow {name}, what an awesome name. What would you like to order?")
    
        # order = str(input("Input your order"))
    
        # if order == "pizza":
        #     print("Here's our pizza selection")
        # elif order == "salad": 
        #     print("Here's our salad selection")
    
    
    # != "pizza" or "salad":
    #     print(f"Sorry {name}, we don't have that.")
    #     order2 = str(input("How about a super awesome pizza? Take a look at our menu, you'll find its delicious"))
    #     print(menu)
            
            #if order2 


#filtered_strings = [string for string in input_strings if filter_word in string]

# Output the result
#print(filtered_strings)


##------------------------------------------------------------------------------
#def awesome_name_statement(name):
#    """this is a simple function for the "wow, awesome name" sentence""" 
#    return f"Wow {name}, what an awesome name. What would you like to order?"

# %%
menu_list = {
    "pizza": {
        "The Basic: Tomato and Cashew Cream Cheese": {"Small": 6.95, "Medium": 8.95, "Large": 10.90},
        "toppings": {"Shitake":0.50, "Jackfruit":0.50, "Sweet Potato":0.50, "Hummus":0.50, "Chickpeas":0.50, "Lentils":0.50, "Tofu":0.50, "Edamame":0.50, "Black Bean":0.50, "Red Cabbage":0.50, "Cucumber":0.50, "Tomato":0.50, "Jicama":0.50, "Fried Green Tomatoes":0.50, "Sun Dried Tomatoes":0.50}
    },
    "salad": {
        "Vegan Caesar": {"Small": 4.95, "Large": 6.95},
        "Vegan Greek": {"Small": 4.95, "Large": 6.95},
        "Cucumber_Tumeric_Tomato": {"Small": 4.95, "Large": 6.95}
    }
}

menu = ("MENU:\n" 
        "Pizza:\n" "- The Basic: Tomato and Cashew Cream Cheese\n"
      "  Small: $6.95\n"
      "  Medium: $8.95\n"
      "  Large: $10.90\n"
        "Additional Toppings: $0.50 \n"
        "  -Shitake\n"
        "  -Jackfruit \n"
        "  -Sweet Potato\n"
        "  -Hummus\n"
        "  -Chickpeas\n"
        "  -Lentils\n"
        "  -Tofu\n" 
        "  -Edamame\n"
        "  -Black Bean\n"
        "  -Red Cabbage\n" 
        "  -Cucumber\n"
        "  -Tomato\n"
        "  -Jicama\n"
        "  -Fried Green Tomatoes\n"
        "  -Sun Dried Tomatoes\n"

      "\nSalads:\n"
      "- Vegan Caesar\n"
      "- Vegan Greek\n"
      "- Cucumber_Tumeric_Tomato\n"
      "  Small: $4.95\n"
      "  Large: $6.95\n")

print(menu)
